# %% [markdown]
# # Examples of algebraically slice GA-knots

# %% [markdown]
# ## Setup
#
# First load and preparse the library.

# %%
import path
from gaknot_lib import notebook_setup
# %preparse gaknot_lib
from gaknot_lib.gaknot import GeneralizedAlgebraicKnot
# Out:
# ERROR:root:Neither /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot/gaknot/signature.sage nor /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot/gaknot/signature.py found.
# Notebook setup complete. Environment configured.
# INFO:
#
# import_sage called with arguments:
# 	module_name: gaknot
# 	package: None
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# ERROR: Neither /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot.sage nor /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot.py found.
# INFO:
#
# import_sage called with arguments:
# 	module_name: signature
# 	package: gaknot
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: LT_signature
# 	package: gaknot
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: signature
# 	package: gaknot
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot
# ERROR: Neither /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot/gaknot/signature.sage nor /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/gaknot/gaknot/signature.py found.
# INFO:
#
# import_sage called with arguments:
# 	module_name: gaknot
# 	package: gaknot
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: H1_branched_cover
# 	package: gaknot
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# Successfully preparsed and reloaded: gaknot

# %%
import ipytest
import pytest

ipytest.autoconfig() # Automatically configures pytest for notebook usage

# %% [markdown]
# Load the content of the file `example_generator.sage`. The file contains a function `slicen`, which, for any given iterated torus knot $K$ generates another iterated torus knot $J$ such that $K \# J$ is algebraically slice.

# %%
load("example_generator.sage")

# %% [markdown]
# ## Test the `slicen` function
