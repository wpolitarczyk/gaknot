# %% [markdown]
# # Testing the `LT_signature` module

# %% [markdown]
# ## Setup

# %%
import path
from gaknot_lib import notebook_setup
import ipytest
import pytest

ipytest.autoconfig(raise_on_error=False)
# Out:
# The ipytest module is not an IPython extension.
# INFO:
#
# import_sage called with arguments:
# 	module_name: signature
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: LT_signature
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: signature
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: gaknot
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: H1_branched_cover
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# Notebook setup complete. Environment configured.

# %%
# %preparse LT_signature
from gaknot_lib.LT_signature import LT_signature_torus_knot, LT_signature_iterated_torus_knot, LT_signature_generalized_algebraic_knot
# Out:
# INFO:
#
# import_sage called with arguments:
# 	module_name: LT_signature
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# INFO:
#
# import_sage called with arguments:
# 	module_name: signature
# 	package: gaknot_lib
# 	path: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function
# Successfully preparsed and reloaded: LT_signature

# %% [markdown]
# ## Helper functions

# %%
def torus_knot_desc_to_txt(desc):
    if not isinstance(desc, (list, tuple)):
        raise TypeError(f'The desc parameter must be a list or a tuple. Got: {type(desc)}.')
    if len(desc) != 2:
        raise ValueError(f'The desc parameter must be of length 2. Got len(desc) = {len(desc)}.')
    return f'T({desc[0]}, {desc[1]})'

def it_torus_knot_desc_to_txt(desc):
    if not isinstance(desc, (list, tuple)):
        raise TypeError(f'The desc parameter must be a list or a tuple. Got: {type(desc)}.')
    return 'T(' + '; '.join([str(a) + ',' + str(b) for a,b in desc]) + ')'
    
def gaknot_desc_to_txt(desc):
    return ' # '.join(['-' * (int(1-sign) // 2) + it_torus_knot_desc_to_txt(knot_desc) for sign, knot_desc in desc])

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Basic Torus Knots (Parametric)
# Verifies total signature jump properties and the signature value at $\theta=1/2$ for a variety of torus knots $T(p,q)$ using parametric testing with 10 cases.

# %% [markdown]
# This test verifies that the `LT_signature_torus_knot` function correctly computes the signature function for several $T(p,q)$ knots. It ensures the signature is zero at $\theta=0$, the total signature jump over the interval $(0, 1)$ is zero, and checks the signature value at $\theta=1/2$ against known results.

# %%
# %%ipytest -vv -W ignore::DeprecationWarning
#
# @pytest.mark.parametrize("p, q, expected_sig", [
#     (2, 3, -2),
#     (2, 5, -4),
#     (2, 7, -6),
#     (3, 4, -6),
#     (3, 5, -8),
#     (3, 7, -8), # Fixed from -4
#     (4, 5, -8),
#     (4, 7, -14),
#     (5, 6, -16), # Fixed from -12
#     (7, 8, -30)
# ])
# def test_lt_signature_torus_knot_basic(p, q, expected_sig):
#     sig = LT_signature_torus_knot(p, q)
#     assert sig(0) == 0
#     assert sig.total_sign_jump() == 0
#
#     # Check the signature value at 1/2
#     assert int(sig(0.5)) == expected_sig
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- /opt/homebrew/anaconda3/envs/sage_env/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/notebooks
# plugins: anyio-4.12.1, nbmake-1.5.5, langsmith-0.7.9
# collecting ... collected 10 items
#
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p0-q0-expected_sig0] PASSED [ 10%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p1-q1-expected_sig1] PASSED [ 20%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p2-q2-expected_sig2] PASSED [ 30%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p3-q3-expected_sig3] PASSED [ 40%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p4-q4-expected_sig4] PASSED [ 50%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p5-q5-expected_sig5] PASSED [ 60%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p6-q6-expected_sig6] PASSED [ 70%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p7-q7-expected_sig7] PASSED [ 80%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p8-q8-expected_sig8] PASSED [ 90%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_basic[p9-q9-expected_sig9] PASSED [100%]
#
# ======================================== 10 passed in 2.58s ========================================

# %% [markdown]
# ### Error Handling
# Ensures that the function correctly identifies invalid input parameters, such as non-coprime (p, q) pairs.

# %% [markdown]
# This test confirms that `LT_signature_torus_knot` properly validates its input parameters. It checks that it raises `ValueError` for non-coprime $p, q$ or $p, q \le 1$, and `TypeError` for non-integer inputs, ensuring robust error handling.

# %%
# %%ipytest -vv -W ignore::DeprecationWarning
#
# @pytest.mark.parametrize("p, q, error_type, match", [
#     (3, 6, ValueError, "relatively prime"),
#     (2, 4, ValueError, "relatively prime"),
#     (10, 15, ValueError, "relatively prime"),
#     (1, 3, ValueError, "must be >1"),
#     (3, 1, ValueError, "must be >1"),
#     (0, 5, ValueError, "must be >1"),
#     (-2, 3, ValueError, "must be >1"),
#     (2.5, 3, TypeError, "have to be integers"),
#     (2, "3", TypeError, "have to be integers"),
#     (None, 3, TypeError, "have to be integers")
# ])
# def test_lt_signature_torus_knot_errors_parametric(p, q, error_type, match):
#     with pytest.raises(error_type, match=match):
#         LT_signature_torus_knot(p, q)
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- /opt/homebrew/anaconda3/envs/sage_env/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/notebooks
# plugins: anyio-4.12.1, nbmake-1.5.5, langsmith-0.7.9
# collecting ... collected 10 items
#
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p0-q0-ValueError-relatively prime] PASSED [ 10%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p1-q1-ValueError-relatively prime] PASSED [ 20%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p2-q2-ValueError-relatively prime] PASSED [ 30%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p3-q3-ValueError-must be >1] PASSED [ 40%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p4-q4-ValueError-must be >1] PASSED [ 50%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p5-q5-ValueError-must be >1] PASSED [ 60%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p6-q6-ValueError-must be >1] PASSED [ 70%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p7-q7-TypeError-have to be integers] PASSED [ 80%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[p8-3-TypeError-have to be integers] PASSED [ 90%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_errors_parametric[None-q9-TypeError-have to be integers] PASSED [100%]
#
# ======================================== 10 passed in 0.04s ========================================

# %% [markdown]
# ### Symmetry Property
# Confirms that the signature function is symmetric with respect to its parameters: $\sigma_{T(p,q)} = \sigma_{T(q,p)}$.

# %% [markdown]
# This test verifies the mathematical property that the signature of a torus knot $T(p, q)$ is identical to the signature of $T(q, p)$. It ensures that the order of the parameters $p$ and $q$ does not affect the output of `LT_signature_torus_knot`.

# %%
# %%ipytest -vv -W ignore::DeprecationWarning
#
# @pytest.mark.parametrize("p, q", [
#     (2, 3), (3, 2),
#     (2, 5), (5, 2),
#     (3, 4), (4, 3),
#     (3, 7), (7, 3),
#     (4, 5), (5, 4),
#     (5, 6), (6, 5),
#     (7, 8), (8, 7),
#     (2, 11), (11, 2),
#     (3, 10), (10, 3),
#     (5, 12), (12, 5)
# ])
# def test_lt_signature_torus_knot_symmetry_parametric(p, q):
#     sig1 = LT_signature_torus_knot(p, q)
#     sig2 = LT_signature_torus_knot(q, p)
#     assert sig1 == sig2
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- /opt/homebrew/anaconda3/envs/sage_env/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/notebooks
# plugins: anyio-4.12.1, nbmake-1.5.5, langsmith-0.7.9
# collecting ... collected 20 items
#
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p0-q0] PASSED [  5%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p1-q1] PASSED [ 10%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p2-q2] PASSED [ 15%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p3-q3] PASSED [ 20%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p4-q4] PASSED [ 25%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p5-q5] PASSED [ 30%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p6-q6] PASSED [ 35%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p7-q7] PASSED [ 40%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p8-q8] PASSED [ 45%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p9-q9] PASSED [ 50%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p10-q10] PASSED [ 55%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p11-q11] PASSED [ 60%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p12-q12] PASSED [ 65%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p13-q13] PASSED [ 70%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p14-q14] PASSED [ 75%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p15-q15] PASSED [ 80%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p16-q16] PASSED [ 85%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p17-q17] PASSED [ 90%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p18-q18] PASSED [ 95%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_torus_knot_symmetry_parametric[p19-q19] PASSED [100%]
#
# ======================================== 20 passed in 0.06s ========================================

# %% [markdown]
# ### Iterated Torus Knots
# Tests the recursive computation of signatures for cabling structures, such as the (6,5)-cable of T(2,3).

# %% [markdown]
# This test focuses on iterated torus knots (satellites). It verifies that `LT_signature_iterated_torus_knot` correctly computes the signature function by ensuring the total signature jump remains zero, as expected for these knots.

# %%
# %%ipytest -vv -W ignore::DeprecationWarning
#
# @pytest.mark.parametrize("desc", [
#     ([(2, 3), (6, 5)]),
#     ([(2, 5), (10, 3)]),
#     ([(3, 4), (12, 5)]),
#     ([(2, 3), (2, 5)]),
#     ([(3, 2), (2, 3)]),
#     ([(2, 3), (6, 5), (30, 7)]),
#     ([(2, 7), (14, 3)]),
#     ([(3, 5), (15, 2)]),
#     ([(2, 3), (2, 7)]),
#     ([(2, 5), (2, 3)])
# ])
# def test_lt_signature_iterated_torus_knot_parametric(desc):
#     iterated_sig = LT_signature_iterated_torus_knot(desc)
#     assert iterated_sig.total_sign_jump() == 0
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- /opt/homebrew/anaconda3/envs/sage_env/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/notebooks
# plugins: anyio-4.12.1, nbmake-1.5.5, langsmith-0.7.9
# collecting ... collected 10 items
#
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc0] PASSED [ 10%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc1] PASSED [ 20%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc2] PASSED [ 30%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc3] PASSED [ 40%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc4] PASSED [ 50%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc5] PASSED [ 60%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc6] PASSED [ 70%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc7] PASSED [ 80%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc8] PASSED [ 90%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_iterated_torus_knot_parametric[desc9] PASSED [100%]
#
# ======================================== 10 passed in 0.04s ========================================

# %% [markdown]
# ### Generalized Algebraic Knots
# Verifies properties for connected sums and concordance inverses, including validation of known algebraically slice knots.

# %% [markdown]
# This test examines generalized algebraic knots, which are connected sums of iterated torus knots and their inverses. It verifies that `LT_signature_generalized_algebraic_knot` correctly identifies algebraically slice knots (where the signature function is zero everywhere) and non-slice knots.

# %%
# %%ipytest -vv -W ignore::DeprecationWarning
#
# @pytest.mark.parametrize("desc, expected_zero", [
#     # T(2,3) # -T(2,3)
#     ([(1, [(2, 3)]), (-1, [(2, 3)])], True),
#     # T(2,5) # -T(2,5)
#     ([(1, [(2, 5)]), (-1, [(2, 5)])], True),
#     # Complex known algebraically slice
#     ([
#         (1, [(2, 3), (5, 2)]),
#         (1, [(3, 2)]),
#         (1, [(5, 3)]),
#         (-1, [(6, 5)])
#     ], True),
#     # Single T(2,3) (not zero)
#     ([(1, [(2, 3)])], False),
#     # T(2,3) # T(3,4) (not zero)
#     ([(1, [(2, 3)]), (1, [(3, 4)])], False),
#     # Concordance inverse sum
#     ([(1, [(2, 3), (6, 5)]), (-1, [(2, 3), (6, 5)])], True),
#     # Sum of two slice candidates (should be slice if both are)
#     ([
#         (1, [(2, 3)]), (-1, [(2, 3)]),
#         (1, [(3, 4)]), (-1, [(3, 4)])
#     ], True),
#     # Three summands (not zero)
#     ([(1, [(2, 3)]), (1, [(3, 4)]), (-1, [(2, 3)])], False),
#     # Empty (technically valid but let's test a simple single component)
#     ([(1, [(2, 7)])], False),
#     # -T(2,3) # T(2,3)
#     ([(-1, [(2, 3)]), (1, [(2, 3)])], True)
# ])
# def test_lt_signature_generalized_algebraic_knot_parametric(desc, expected_zero):
#     sig = LT_signature_generalized_algebraic_knot(desc)
#     if expected_zero:
#         assert sig.is_zero_everywhere()
#     else:
#         assert not sig.is_zero_everywhere()
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- /opt/homebrew/anaconda3/envs/sage_env/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/wojtek/Library/CloudStorage/GoogleDrive-w.politarczyk@uw.edu.pl/My Drive/mat/git-projects/signature_function/notebooks
# plugins: anyio-4.12.1, nbmake-1.5.5, langsmith-0.7.9
# collecting ... collected 10 items
#
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc0-True] PASSED [ 10%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc1-True] PASSED [ 20%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc2-True] PASSED [ 30%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc3-False] PASSED [ 40%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc4-False] PASSED [ 50%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc5-True] PASSED [ 60%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc6-True] PASSED [ 70%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc7-False] PASSED [ 80%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc8-False] PASSED [ 90%]
# t_e82375b45a9a484ba9b8e40b7e88df99.py::test_lt_signature_generalized_algebraic_knot_parametric[desc9-True] PASSED [100%]
#
# ======================================== 10 passed in 0.04s ========================================
